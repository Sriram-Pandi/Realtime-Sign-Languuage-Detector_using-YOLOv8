# %%
# !nvidia-smi
# Out:
# Wed Apr 26 00:59:15 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 530.2/530.2 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.5/199.5 kB 13.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import Image, display
from IPython import display
display.clear_output()
# !yolo checks

# %%
# !pip install roboflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !mkdir /content/Yolov8SignLanguage-3/datasets
# %cd /content/Yolov8SignLanguage-3/datasets


from roboflow import Roboflow
rf = Roboflow(api_key="UFADqfwnCkny5wS2P4rm")
project = rf.workspace("signlanguagedetection").project("yolosignlanguage-detection")
dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.87, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to YOLOsignlanguage-detection-1 in yolov8:: 100%|██████████| 2980/2980 [00:01<00:00, 2023.84it/s]

# %%
# !yolo task=detect mode=train model=/content/yolov8s.pt data=/content/YOLOsignlanguage-detection-1/data.yaml epochs=60 imgsz=640
# Out:
# Ultralytics YOLOv8.0.87 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
